# %%
import pandas as pd

# %%
august = pd.read_csv("Data/JC-201908-citibike-tripdata.csv")
september = pd.read_csv("Data/JC-201909-citibike-tripdata.csv")
october = pd.read_csv("Data/JC-201910-citibike-tripdata.csv")
november = pd.read_csv("Data/JC-201911-citibike-tripdata.csv")
december = pd.read_csv("Data/JC-201912-citibike-tripdata.csv")
january = pd.read_csv("Data/JC-202001-citibike-tripdata.csv")

# %%
august.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1           172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2           525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3           219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4           262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
#
#    start station id start station name  start station latitude  \
# 0              3205  JC Medical Center               40.716540
# 1              3279        Dixon Mills               40.721630
# 2              3199       Newport Pkwy               40.728745
# 3              3187          Warren St               40.721124
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id    end station name  \
# 0               -74.049638            3192  Liberty Light Rail
# ...

# %%
df = august.append([september,october,november,december,january],ignore_index = True)

# %%
df
# Out:
#         tripduration                 starttime                  stoptime  \
# 0                261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1                172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2                525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3                219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4                262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
# ...              ...                       ...                       ...
# 216748           544  2020-01-31 23:29:29.3910  2020-01-31 23:38:33.6910
# 216749           122  2020-01-31 23:30:59.3670  2020-01-31 23:33:01.6870
# 216750           201  2020-01-31 23:42:34.8460  2020-01-31 23:45:55.8780
# 216751           300  2020-01-31 23:45:00.6800  2020-01-31 23:50:00.8740
# 216752           721  2020-01-31 23:48:35.1700  2020-02-01 00:00:36.4060
#
#         start station id          start station name  start station latitude  \
# ...

# %%
df.count()
# Out:
# tripduration               216753
# starttime                  216753
# stoptime                   216753
# start station id           216753
# start station name         216753
# start station latitude     216753
# start station longitude    216753
# end station id             216753
# end station name           216753
# end station latitude       216753
# end station longitude      216753
# bikeid                     216753
# usertype                   216753
# birth year                 216753
# gender                     216753
# dtype: int64

# %%
df["gender"].value_counts()
# Out:
# 1    150465
# 2     52439
# 0     13849
# Name: gender, dtype: int64

# %%
df["gender"].replace([0,1,2],["unknown","male","female"],inplace=True)

# %%
df["gender"].unique()
# Out:
# array(['male', 'female', 'unknown'], dtype=object)

# %%
df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           261  2019-08-01 00:14:55.9900  2019-08-01 00:19:17.4780
# 1           172  2019-08-01 00:23:06.9910  2019-08-01 00:25:59.1480
# 2           525  2019-08-01 00:23:28.6170  2019-08-01 00:32:13.7000
# 3           219  2019-08-01 00:32:36.1410  2019-08-01 00:36:15.2730
# 4           262  2019-08-01 00:41:26.6700  2019-08-01 00:45:49.3530
#
#    start station id start station name  start station latitude  \
# 0              3205  JC Medical Center               40.716540
# 1              3279        Dixon Mills               40.721630
# 2              3199       Newport Pkwy               40.728745
# 3              3187          Warren St               40.721124
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id    end station name  \
# 0               -74.049638            3192  Liberty Light Rail
# ...

# %%
df.to_csv("Data/final_df.csv")
